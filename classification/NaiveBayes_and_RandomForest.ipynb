# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/CZ4034 IR/Classification/Merged_with_Labelled_data.csv')

# %%
df
# Out:
#       Unnamed: 0         username  \
# 0              4      Shamrock680
# 1              5         BskdTina
# 2             12         PigsterC
# 3             19  Stockwa60818438
# 4             21       CEOSCRYPTO
# ...          ...              ...
# 8562        8740          balajis
# 8563        8741          balajis
# 8564        8742          balajis
# 8565        8743          balajis
# 8566        8744          balajis
#
#                                                 content  \
# 0     @robertakanda @RobertOstler All you need to do...
# 1     Buying Bitcoins on the Bitstamp exchange. This...
# 2     A quick update on the recent performance of Pi...
# 3                               BTC bounce at 60300 🚀🚀🚀
# 4     Sounds like a good #CryptoEqualsOptions recipe...
# ...                                                 ...
# 8562  Gold was already defeated by the state. See Ex...
# 8563  Is Bitcoin becoming legal tender in Brazil? Ma...
# 8564  Decentralized custody is easier if you go Bitc...
# 8565  If you believe the premises, you believe the c...
# 8566  When PG&amp;E fails, get a generator.\nWhen th...
#
#                            date      country  replyCount  retweetCount  \
# 0     2021-12-27 23:52:56+00:00    Argentina           0             0
# 1     2021-12-27 22:30:40+00:00    Argentina           0             0
# 2     2021-12-26 22:28:22+00:00    Argentina           0             1
# 3     2021-10-29 07:23:35+00:00  Switzerland           0             0
# 4     2021-12-26 20:05:07+00:00    Argentina           0             0
# ...                         ...          ...         ...           ...
# 8562  2021-10-14 01:06:25+00:00          NaN          26            65
# 8563  2021-10-07 15:59:05+00:00          NaN           7            20
# 8564  2021-10-02 12:05:07+00:00          NaN          19            23
# 8565  2021-10-02 09:27:17+00:00          NaN           8            25
# 8566  2021-09-30 14:36:46+00:00          NaN          24            17
#
#       likeCount                                                url  sentiment  \
# 0             0  https://twitter.com/Shamrock680/status/1475615...        1.0
# 1             3  https://twitter.com/BskdTina/status/1475595009...        1.0
# 2             1  https://twitter.com/PigsterC/status/1475232043...        1.0
# 3             0  https://twitter.com/Stockwa60818438/status/145...        1.0
# 4             1  https://twitter.com/CEOSCRYPTO/status/14751959...        1.0
# ...         ...                                                ...        ...
# 8562        376  https://twitter.com/balajis/status/14484551152...        NaN
# 8563        160  https://twitter.com/balajis/status/14461430485...        NaN
# 8564        379  https://twitter.com/balajis/status/14442722281...        NaN
# 8565        194  https://twitter.com/balajis/status/14442325112...        NaN
# 8566        148  https://twitter.com/balajis/status/14435856191...        NaN
#
#       ... vader_neu vader_pos  vader_comp  \
# 0     ...     1.000     0.000      0.0000
# 1     ...     0.850     0.150      0.5574
# 2     ...     0.886     0.114      0.6115
# 3     ...     1.000     0.000      0.0000
# 4     ...     0.671     0.329      0.6597
# ...   ...       ...       ...         ...
# 8562  ...     0.726     0.035     -0.8766
# 8563  ...     0.744     0.256      0.8750
# 8564  ...     0.813     0.108      0.0516
# 8565  ...     1.000     0.000      0.0000
# 8566  ...     0.709     0.000     -0.8885
#
#                                              cleantext2  class  \
# 0     all you need to do be keep buy utc and eth and...      0
# 1     buy bitcoin on the bitstamp exchange this type...      1
# 2     a quick update on the recent performance of po...      1
# 3              utc bounce at 60300 rocket rocket rocket      0
# 4     sound like a good recipe to me smiling_face hu...      1
# ...                                                 ...    ...
# 8562  gold be already defeat by the state see execut...     -1
# 8563  be bitcoin become legal tender in brazil maybe...      1
# 8564  decentralize custody be easier if you go bitco...     -1
# 8565  if you believe the premise you believe the con...      0
# 8566  when pg amp e fail get a generator when the cd...     -1
#
#       TextBlob_Polarity TextBlob_Subjectivity  TextBlob_Analysis  \
# 0              0.000000              0.000000                  0
# 1              0.162500              0.637500                  1
# 2              0.283333              0.500000                  1
# 3              0.000000              0.000000                  0
# 4              0.550000              0.500000                  1
# ...                 ...                   ...                ...
# 8562          -0.042857              0.448571                 -1
# 8563           0.381818              0.461364                  1
# 8564           0.030556              0.566667                  1
# 8565          -0.018519              0.196296                 -1
# 8566          -0.316667              0.250000                 -1
#
#       vader_vs_textblob  ground_truth
# 0                   NaN           NaN
# 1                   NaN           NaN
# 2                   NaN           NaN
# 3                   NaN           NaN
# 4                   NaN           NaN
# ...                 ...           ...
# 8562                NaN           NaN
# 8563                NaN           NaN
# 8564                NaN           NaN
# 8565                NaN           NaN
# 8566                NaN           NaN
#
# [8567 rows x 23 columns]

# %%
df.shape
# Out:
# (8567, 23)

# %%
eval=df[df['sentiment'].notnull()]

# %%
eval
# Out:
#       Unnamed: 0         username  \
# 0              4      Shamrock680
# 1              5         BskdTina
# 2             12         PigsterC
# 3             19  Stockwa60818438
# 4             21       CEOSCRYPTO
# ...          ...              ...
# 1144        7684             lopp
# 1145        7695             lopp
# 1146        7746      scottmelker
# 1147        7749      scottmelker
# 1148        7750      scottmelker
#
#                                                 content  \
# 0     @robertakanda @RobertOstler All you need to do...
# 1     Buying Bitcoins on the Bitstamp exchange. This...
# 2     A quick update on the recent performance of Pi...
# 3                               BTC bounce at 60300 🚀🚀🚀
# 4     Sounds like a good #CryptoEqualsOptions recipe...
# ...                                                 ...
# 1144  @NeerajKA @gladstein @bitcoin_hermit @coryklip...
# 1145  @gladstein @udiWertheimer i thought everything...
# 1146  The #Bitcoin chart looks so shitty that I'm al...
# 1147  The market is bleeding, #Bitcoin took a Mutomb...
# 1148  The 4 tokens are $ATLAS $POLIS $TLM and $ILV, ...
#
#                            date      country  replyCount  retweetCount  \
# 0     2021-12-27 23:52:56+00:00    Argentina           0             0
# 1     2021-12-27 22:30:40+00:00    Argentina           0             0
# 2     2021-12-26 22:28:22+00:00    Argentina           0             1
# 3     2021-10-29 07:23:35+00:00  Switzerland           0             0
# 4     2021-12-26 20:05:07+00:00    Argentina           0             0
# ...                         ...          ...         ...           ...
# 1144  2021-12-07 22:48:43+00:00          NaN           1             2
# 1145  2021-11-22 21:03:35+00:00          NaN           4             1
# 1146  2021-12-14 17:54:39+00:00          NaN         295           153
# 1147  2021-12-10 15:03:25+00:00          NaN          24             6
# 1148  2021-12-09 22:22:28+00:00          NaN          50            38
#
#       likeCount                                                url  sentiment  \
# 0             0  https://twitter.com/Shamrock680/status/1475615...        1.0
# 1             3  https://twitter.com/BskdTina/status/1475595009...        1.0
# 2             1  https://twitter.com/PigsterC/status/1475232043...        1.0
# 3             0  https://twitter.com/Stockwa60818438/status/145...        1.0
# 4             1  https://twitter.com/CEOSCRYPTO/status/14751959...        1.0
# ...         ...                                                ...        ...
# 1144         12  https://twitter.com/lopp/status/14683517954456...       -1.0
# 1145         59  https://twitter.com/lopp/status/14628895224427...       -1.0
# 1146       3444  https://twitter.com/scottmelker/status/1470814...       -1.0
# 1147        109  https://twitter.com/scottmelker/status/1469321...       -1.0
# 1148        212  https://twitter.com/scottmelker/status/1469069...       -1.0
#
#       ... vader_neu vader_pos  vader_comp  \
# 0     ...     1.000     0.000      0.0000
# 1     ...     0.850     0.150      0.5574
# 2     ...     0.886     0.114      0.6115
# 3     ...     1.000     0.000      0.0000
# 4     ...     0.671     0.329      0.6597
# ...   ...       ...       ...         ...
# 1144  ...     0.826     0.095      0.1154
# 1145  ...     0.775     0.225      0.4404
# 1146  ...     0.866     0.134      0.1796
# 1147  ...     0.752     0.134      0.1531
# 1148  ...     0.970     0.000     -0.0572
#
#                                              cleantext2  class  \
# 0     all you need to do be keep buy utc and eth and...      0
# 1     buy bitcoin on the bitstamp exchange this type...      1
# 2     a quick update on the recent performance of po...      1
# 3              utc bounce at 60300 rocket rocket rocket      0
# 4     sound like a good recipe to me smiling_face hu...      1
# ...                                                 ...    ...
# 1144  i do not know how you define hurt bitcoin but ...     -1
# 1145  i think everything be good for bitcoin go to b...      1
# 1146  the chart look so shift that i be almost convi...      1
# 1147  the market be bleed take a mutombo level rejec...     -1
# 1148  the 4 tokens be atlas polis tl and il all of w...     -1
#
#       TextBlob_Polarity TextBlob_Subjectivity  TextBlob_Analysis  \
# 0              0.000000              0.000000                  0
# 1              0.162500              0.637500                  1
# 2              0.283333              0.500000                  1
# 3              0.000000              0.000000                  0
# 4              0.550000              0.500000                  1
# ...                 ...                   ...                ...
# 1144           0.214286              0.571429                  1
# 1145           0.350000              0.450000                  1
# 1146           0.000000              0.000000                  0
# 1147           0.312121              0.500000                  1
# 1148           0.150000              1.000000                  1
#
#       vader_vs_textblob  ground_truth
# 0                   NaN           NaN
# 1                   NaN           NaN
# 2                   NaN           NaN
# 3                   NaN           NaN
# 4                   NaN           NaN
# ...                 ...           ...
# 1144                NaN           NaN
# 1145                NaN           NaN
# 1146                NaN           NaN
# 1147                NaN           NaN
# 1148                NaN           NaN
#
# [1149 rows x 23 columns]

# %%
eval['sentiment'].value_counts()
# Out:
#  1.0    637
#  0.0    330
# -1.0    182
# Name: sentiment, dtype: int64

# %%
train=df[df['ground_truth'].notnull()]

# %%
train
# Out:
#       Unnamed: 0        username  \
# 1149           0     itzeyrnz_21
# 1150           6  GillBa8scrypto
# 1151           9    Skywalker01m
# 1152          14      rBelgriego
# 1153          15      StateyTeam
# ...          ...             ...
# 3978        3753      Putonjones
# 3979        3754      alexochoac
# 3980        3755       kryptobia
# 3981        3756        EAKrypto
# 3982        3757       MaxMasher
#
#                                                 content  \
# 1149  @chitaglorya__ @BTC_NFT @CryptoZillaVC @Block_...
# 1150  @yvtweets I'm working this myself...great proj...
# 1151              At least 50 bitcoins @ZentralratJuden
# 1152  Show me your bank interest 🏦\nEarnings by http...
# 1153  Here we are with the Fax with Max Tik Tok page...
# ...                                                 ...
# 3978      Up all night watching and buying #Bitcoin 💪🏽💰
# 3979  #Bitcoin miners always look for places with th...
# 3980  Dubai’s Upcoming Crypto Expo to Witness Over 3...
# 3981  Thumbs up 👍 who got into BTC when it was under...
# 3982  this Winter a new Season era is coming #Hodl 🌕...
#
#                            date    country  replyCount  retweetCount  \
# 1149  2021-11-14 03:15:09+00:00     Israel           0             0
# 1150  2021-12-27 23:59:50+00:00  Argentina           0             0
# 1151  2021-11-14 18:12:30+00:00     France           1             0
# 1152  2021-11-11 13:36:08+00:00     France           2             4
# 1153  2021-11-08 02:43:14+00:00     Mexico           1             2
# ...                         ...        ...         ...           ...
# 3978  2021-07-26 06:40:03+00:00     Mexico           0             0
# 3979  2021-09-23 05:06:37+00:00    Germany           0             1
# 3980  2021-09-25 17:32:08+00:00  Argentina           0             0
# 3981  2021-01-02 17:28:03+00:00     France           0             0
# 3982  2021-08-20 13:55:14+00:00     France           2             0
#
#       likeCount                                                url  sentiment  \
# 1149          0  https://twitter.com/itzeyrnz_21/status/1459721...        NaN
# 1150          0  https://twitter.com/GillBa8scrypto/status/1475...        NaN
# 1151          0  https://twitter.com/Skywalker01m/status/145994...        NaN
# 1152         15  https://twitter.com/rBelgriego/status/14587906...        NaN
# 1153          0  https://twitter.com/StateyTeam/status/14575391...        NaN
# ...         ...                                                ...        ...
# 3978          0  https://twitter.com/Putonjones/status/14195480...        NaN
# 3979          0  https://twitter.com/alexochoac/status/14409054...        NaN
# 3980          0  https://twitter.com/kryptobia/status/144181780...        NaN
# 3981          0  https://twitter.com/EAKrypto/status/1345421612...        NaN
# 3982          2  https://twitter.com/MaxMasher/status/142871726...        NaN
#
#       ... vader_neu vader_pos  vader_comp  \
# 1149  ...     0.374     0.626      0.8939
# 1150  ...     0.687     0.313      0.6249
# 1151  ...     1.000     0.000      0.0000
# 1152  ...     0.769     0.231      0.4588
# 1153  ...     1.000     0.000      0.0000
# ...   ...       ...       ...         ...
# 3978  ...     1.000     0.000      0.0000
# 3979  ...     0.676     0.237      0.6979
# 3980  ...     1.000     0.000      0.0000
# 3981  ...     1.000     0.000      0.0000
# 3982  ...     1.000     0.000      0.0000
#
#                                              cleantext2  class  \
# 1149  thank you for this huge opportunity to win fol...      1
# 1150  i be work this myself great project lot of pot...      1
# 1151                                at least 50 bitcoin      0
# 1152  show me your bank interest bank earn by loudsp...      1
# 1153  here we be with the fax with max tik tok page ...      0
# ...                                                 ...    ...
# 3978  up all night watch and buy fixed_bikes_medium_...      0
# 3979  miners always look for place with the cheapest...     -1
# 3980  dubai s upcoming crypto expo to witness over 3...      0
# 3981  thumb up thumbs_up who get into utc when it be...      0
# 3982  this winter a new season era be come full_moon...      0
#
#       TextBlob_Polarity TextBlob_Subjectivity  TextBlob_Analysis  \
# 1149           0.600000              0.650000                  1
# 1150           0.400000              0.875000                  1
# 1151          -0.300000              0.400000                 -1
# 1152           0.000000              0.000000                  0
# 1153           0.000000              0.000000                  0
# ...                 ...                   ...                ...
# 3978           0.000000              0.000000                  0
# 3979          -0.200000              0.500000                 -1
# 3980           0.062500              0.500000                  1
# 3981           0.000000              0.000000                  0
# 3982           0.136364              0.454545                  1
#
#       vader_vs_textblob  ground_truth
# 1149                NaN           1.0
# 1150                NaN           1.0
# 1151                NaN           1.0
# 1152                NaN           1.0
# 1153                NaN           0.0
# ...                 ...           ...
# 3978                NaN           0.0
# 3979                NaN          -1.0
# 3980                NaN           0.0
# 3981                NaN           0.0
# 3982                NaN           0.0
#
# [2834 rows x 23 columns]

# %%
train['ground_truth'].value_counts()
# Out:
#  0.0    1539
#  1.0     760
# -1.0     535
# Name: ground_truth, dtype: int64

# %%
test=df[df['ground_truth'].isnull() & df['sentiment'].isnull()]

# %%
test
# Out:
#       Unnamed: 0         username  \
# 3983        3758  Jordanthegrea21
# 3984        3759   jaredmckiernan
# 3985        3760      darealcamms
# 3986        3761   Advertiseshout
# 3987        3762  LarryCallahanII
# ...          ...              ...
# 8562        8740          balajis
# 8563        8741          balajis
# 8564        8742          balajis
# 8565        8743          balajis
# 8566        8744          balajis
#
#                                                 content  \
# 3983  @CryptoEva01 @don_Aleksander I wonder the impa...
# 3984  it’s funny how nothing the news is that Tesla ...
# 3985  If a bitch ever call me ugly she’s a hating bi...
# 3986  Billionaire Mike Novogratz says the Bitcoin ma...
# 3987  #cryptocurrency is a way to unite people aroun...
# ...                                                 ...
# 8562  Gold was already defeated by the state. See Ex...
# 8563  Is Bitcoin becoming legal tender in Brazil? Ma...
# 8564  Decentralized custody is easier if you go Bitc...
# 8565  If you believe the premises, you believe the c...
# 8566  When PG&amp;E fails, get a generator.\nWhen th...
#
#                            date        country  replyCount  retweetCount  \
# 3983  2021-02-08 23:50:04+00:00         Canada           1             0
# 3984  2021-02-08 17:02:18+00:00    El Salvador           1             0
# 3985  2021-01-20 06:49:38+00:00  United States           0             0
# 3986  2021-09-26 23:25:26+00:00      Argentina           0             0
# 3987  2021-05-19 15:56:04+00:00         Mexico           0             0
# ...                         ...            ...         ...           ...
# 8562  2021-10-14 01:06:25+00:00            NaN          26            65
# 8563  2021-10-07 15:59:05+00:00            NaN           7            20
# 8564  2021-10-02 12:05:07+00:00            NaN          19            23
# 8565  2021-10-02 09:27:17+00:00            NaN           8            25
# 8566  2021-09-30 14:36:46+00:00            NaN          24            17
#
#       likeCount                                                url  sentiment  \
# 3983          1  https://twitter.com/Jordanthegrea21/status/135...        NaN
# 3984          1  https://twitter.com/jaredmckiernan/status/1358...        NaN
# 3985          0  https://twitter.com/darealcamms/status/1351783...        NaN
# 3986          0  https://twitter.com/Advertiseshout/status/1442...        NaN
# 3987          0  https://twitter.com/LarryCallahanII/status/139...        NaN
# ...         ...                                                ...        ...
# 8562        376  https://twitter.com/balajis/status/14484551152...        NaN
# 8563        160  https://twitter.com/balajis/status/14461430485...        NaN
# 8564        379  https://twitter.com/balajis/status/14442722281...        NaN
# 8565        194  https://twitter.com/balajis/status/14442325112...        NaN
# 8566        148  https://twitter.com/balajis/status/14435856191...        NaN
#
#       ... vader_neu vader_pos  vader_comp  \
# 3983  ...     0.694     0.233      0.6808
# 3984  ...     0.833     0.130      0.6808
# 3985  ...     0.485     0.162     -0.7845
# 3986  ...     0.909     0.091      0.2732
# 3987  ...     0.898     0.102      0.5789
# ...   ...       ...       ...         ...
# 8562  ...     0.726     0.035     -0.8766
# 8563  ...     0.744     0.256      0.8750
# 8564  ...     0.813     0.108      0.0516
# 8565  ...     1.000     0.000      0.0000
# 8566  ...     0.709     0.000     -0.8885
#
#                                              cleantext2  class  \
# 3983  i wonder the impact of a 10000 utc drop incomi...     -1
# 3984  it be funny how nothing the news be that tesla...     -1
# 3985  if a bitch ever call me ugly she be a hat bitc...     -1
# 3986  billionaire mike novogratz say the bitcoin mar...      1
# 3987  be a way to unite people around the globe it a...      1
# ...                                                 ...    ...
# 8562  gold be already defeat by the state see execut...     -1
# 8563  be bitcoin become legal tender in brazil maybe...      1
# 8564  decentralize custody be easier if you go bitco...     -1
# 8565  if you believe the premise you believe the con...      0
# 8566  when pg amp e fail get a generator when the cd...     -1
#
#       TextBlob_Polarity TextBlob_Subjectivity  TextBlob_Analysis  \
# 3983           0.750000              0.400000                  1
# 3984           0.250000              1.000000                  1
# 3985          -0.700000              0.833333                 -1
# 3986          -0.166667              0.066667                 -1
# 3987           0.150000              0.150000                  1
# ...                 ...                   ...                ...
# 8562          -0.042857              0.448571                 -1
# 8563           0.381818              0.461364                  1
# 8564           0.030556              0.566667                  1
# 8565          -0.018519              0.196296                 -1
# 8566          -0.316667              0.250000                 -1
#
#       vader_vs_textblob  ground_truth
# 3983                NaN           NaN
# 3984                NaN           NaN
# 3985                NaN           NaN
# 3986                NaN           NaN
# 3987                NaN           NaN
# ...                 ...           ...
# 8562                NaN           NaN
# 8563                NaN           NaN
# 8564                NaN           NaN
# 8565                NaN           NaN
# 8566                NaN           NaN
#
# [4584 rows x 23 columns]

# %%
import pandas as pd
train=pd.read_csv('/content/drive/MyDrive/CZ4034IR/Classification/inference/hand-labelled-new/train_data_inference_diff_processing.csv')

# %%
eval=pd.read_csv('/content/drive/MyDrive/CZ4034IR/Classification/inference/hand-labelled-new/test_data_inference_diff_processing.csv')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer()
tweet_tfidf_train=tfidf.fit_transform(train['processed_content'])

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
MNB=MultinomialNB()
MNB.fit(tweet_tfidf_train,train['sentiment'])
# Out:
# MultinomialNB()

# %%
from sklearn import metrics
tweet_tfidf_eval=tfidf.transform(eval['processed_content'])
predicted=MNB.predict(tweet_tfidf_eval)
accuracy_score=metrics.accuracy_score(predicted,eval['sentiment'])

# %%
precision = round(metrics.precision_score(eval['sentiment'],predicted, average="weighted"), 3)
recall = round(metrics.recall_score(eval['sentiment'],predicted, average="weighted"), 3)
nb_f1_score = round(metrics.f1_score(eval['sentiment'], predicted, average="weighted"), 3)

# %%
print(precision,recall,nb_f1_score)
# Out:
# 0.675 0.5 0.371

# %%
print(accuracy_score)
# Out:
# 0.4995648389904265

# %%
predicted
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(MNB, tweet_tfidf_eval, eval['sentiment']) 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
MNB=MultinomialNB()
tfidf=TfidfVectorizer()
tweet_tfidf_train=tfidf.fit_transform(train['cleantext_no_spell'])
MNB.fit(tweet_tfidf_train,train['sentiment'])
# Out:
# MultinomialNB()

# %%
from sklearn import metrics
tweet_tfidf_eval=tfidf.transform(eval['cleantext_no_spell'])
predicted=MNB.predict(tweet_tfidf_eval)
accuracy_score=metrics.accuracy_score(predicted,eval['sentiment'])

# %%
precision = round(metrics.precision_score(eval['sentiment'],predicted, average="weighted"), 3)
recall = round(metrics.recall_score(eval['sentiment'],predicted, average="weighted"), 3)
nb_f1_score = round(metrics.f1_score(eval['sentiment'], predicted, average="weighted"), 3)

# %%
print(precision,recall,nb_f1_score)
# Out:
# 0.616 0.498 0.367

# %%
print(accuracy_score)
# Out:
# 0.4978241949521323

# %%
predicted
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(MNB, tweet_tfidf_eval, eval['sentiment']) 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.naive_bayes import GaussianNB
GNB=GaussianNB()
tfidf=TfidfVectorizer()
tweet_tfidf_train=tfidf.fit_transform(train['processed_content'])
GNB.fit(tweet_tfidf_train.toarray(),train['sentiment'])
# Out:
# GaussianNB()

# %%
from sklearn import metrics
tweet_tfidf_eval=tfidf.transform(eval['processed_content'])
predicted=GNB.predict(tweet_tfidf_eval.toarray())
accuracy_score=round(metrics.accuracy_score(predicted,eval['sentiment']), 3)

# %%
precision = round(metrics.precision_score(eval['sentiment'],predicted, average="weighted"), 3)
recall = round(metrics.recall_score(eval['sentiment'],predicted, average="weighted"), 3)
nb_f1_score = round(metrics.f1_score(eval['sentiment'], predicted, average="weighted"), 3)

# %%
print(precision,recall,nb_f1_score)
# Out:
# 0.468 0.413 0.421

# %%
print(accuracy_score)
# Out:
# 0.413

# %%
print("Accuracy: ", accuracy_score)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1_score: ", nb_f1_score)
# Out:
# Accuracy:  0.413
# Precision:  0.468
# Recall:  0.413
# F1_score:  0.421

# %%
predicted
# Out:
# array([-1.,  1.,  0., ..., -1., -1.,  0.])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(GNB, tweet_tfidf_eval.toarray(), eval['sentiment']) 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.naive_bayes import GaussianNB
GNB=GaussianNB()
tfidf=TfidfVectorizer()
tweet_tfidf_train=tfidf.fit_transform(train['cleantext_no_spell'])
GNB.fit(tweet_tfidf_train.toarray(),train['sentiment'])
# Out:
# GaussianNB()

# %%
from sklearn import metrics
tweet_tfidf_eval=tfidf.transform(eval['cleantext_no_spell'])
predicted=GNB.predict(tweet_tfidf_eval.toarray())
accuracy_score= round(metrics.accuracy_score(predicted,eval['sentiment']), 3)

# %%
precision = metrics.precision_score(eval['sentiment'],predicted, average="weighted")
recall = metrics.recall_score(eval['sentiment'],predicted, average="weighted")
nb_f1_score = metrics.f1_score(eval['sentiment'], predicted, average="weighted")

# %%
print(precision,recall,nb_f1_score)
# Out:
# 0.46254854842672405 0.4081810269799826 0.41614667824532037

# %%
print(accuracy_score)
# Out:
# 0.408

# %%
predicted
# Out:
# array([-1.,  1.,  0., ..., -1., -1.,  0.])

# %%
print("Accuracy: ", accuracy_score)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1_score: ", nb_f1_score)
# Out:
# Accuracy:  0.408
# Precision:  0.46254854842672405
# Recall:  0.4081810269799826
# F1_score:  0.41614667824532037

# %%
print("Accuracy: ", 0.408)
print("Precision: ", 0.462)
print("Recall: ", 0.408)
print("F1_score: ", 0.416)
# Out:
# Accuracy:  0.408
# Precision:  0.462
# Recall:  0.408
# F1_score:  0.416

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(GNB, tweet_tfidf_eval.toarray(), eval['sentiment']) 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
import numpy as np
np.unique(predicted, return_counts=True)
# Out:
# (array([-1.,  0.,  1.]), array([456, 352, 341]))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

tfidf=TfidfVectorizer()
tweet_tfidf_train=tfidf.fit_transform(train['processed_content'])

tweet_tfidf_eval=tfidf.transform(eval['processed_content'])
rf = RandomForestClassifier()
scores = cross_val_score(rf,tweet_tfidf_train,train['sentiment'],cv=5)

# %%
print(scores)
scores.mean()
# Out:
# [0.58553792 0.55908289 0.56084656 0.5696649  0.54416961]
# 0.5638603772879391

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %%
from sklearn.model_selection import GridSearchCV

rf = RandomForestClassifier()
parameters = {
    'n_estimators': [5,50,100],
    'max_depth': [2,10,20,None]
}

cv = GridSearchCV(rf,parameters)
cv.fit(tweet_tfidf_train,train['sentiment'])
print_results(cv)
# Out:
# BEST PARAMS: {'max_depth': None, 'n_estimators': 100}
#
# 0.544 (+/-0.004) for {'max_depth': 2, 'n_estimators': 5}
# 0.543 (+/-0.001) for {'max_depth': 2, 'n_estimators': 50}
# 0.543 (+/-0.001) for {'max_depth': 2, 'n_estimators': 100}
# 0.544 (+/-0.03) for {'max_depth': 10, 'n_estimators': 5}
# 0.543 (+/-0.002) for {'max_depth': 10, 'n_estimators': 50}
# 0.543 (+/-0.001) for {'max_depth': 10, 'n_estimators': 100}
# 0.544 (+/-0.025) for {'max_depth': 20, 'n_estimators': 5}
# 0.546 (+/-0.014) for {'max_depth': 20, 'n_estimators': 50}
# 0.546 (+/-0.008) for {'max_depth': 20, 'n_estimators': 100}
# 0.545 (+/-0.037) for {'max_depth': None, 'n_estimators': 5}
# 0.564 (+/-0.034) for {'max_depth': None, 'n_estimators': 50}
# 0.57 (+/-0.027) for {'max_depth': None, 'n_estimators': 100}

# %%
rf3 = RandomForestClassifier(n_estimators=50,max_depth=None)
rf3.fit(tweet_tfidf_train,train['sentiment'])
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
y_pred = rf3.predict(tweet_tfidf_eval)
accuracy = round(metrics.accuracy_score(eval['sentiment'],y_pred), 3)
precision = round(metrics.precision_score(eval['sentiment'],y_pred,average="weighted"), 3)
recall = round(metrics.recall_score(eval['sentiment'],y_pred,average="weighted"), 3)
rf_f1_score = round(metrics.f1_score(eval['sentiment'], y_pred, average="weighted"), 3)
print('MAX DEPTH: {} / # OF EST: {} -- A: {} / P: {} / R: {}'.format(rf3.max_depth,
                                                                         rf3.n_estimators,
                                                                         accuracy,
                                                                         precision,
                                                                         recall))
# Out:
# MAX DEPTH: None / # OF EST: 50 -- A: 0.563 / P: 0.59 / R: 0.563

# %%
print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1_score: ", rf_f1_score)
# Out:
# Accuracy:  0.563
# Precision:  0.59
# Recall:  0.563
# F1_score:  0.522

# %%
print(rf_f1_score)
# Out:
# 0.522

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(rf3, tweet_tfidf_eval, eval['sentiment']) 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

tfidf=TfidfVectorizer()
tweet_tfidf_train=tfidf.fit_transform(train['cleantext_no_spell'])

tweet_tfidf_eval=tfidf.transform(eval['cleantext_no_spell'])
rf = RandomForestClassifier()
scores = cross_val_score(rf,tweet_tfidf_train,train['sentiment'],cv=5)

# %%
print(scores)
scores.mean()
# Out:
# [0.58906526 0.56613757 0.56613757 0.5696649  0.5459364 ]
# 0.5673883373530016

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %%
from sklearn.model_selection import GridSearchCV

rf = RandomForestClassifier()
parameters = {
    'n_estimators': [5,50,100],
    'max_depth': [2,10,20,None]
}

cv = GridSearchCV(rf,parameters)
cv.fit(tweet_tfidf_train,train['sentiment'])
print_results(cv)
# Out:
# BEST PARAMS: {'max_depth': None, 'n_estimators': 100}
#
# 0.544 (+/-0.005) for {'max_depth': 2, 'n_estimators': 5}
# 0.543 (+/-0.001) for {'max_depth': 2, 'n_estimators': 50}
# 0.543 (+/-0.001) for {'max_depth': 2, 'n_estimators': 100}
# 0.547 (+/-0.012) for {'max_depth': 10, 'n_estimators': 5}
# 0.543 (+/-0.003) for {'max_depth': 10, 'n_estimators': 50}
# 0.544 (+/-0.004) for {'max_depth': 10, 'n_estimators': 100}
# 0.55 (+/-0.029) for {'max_depth': 20, 'n_estimators': 5}
# 0.552 (+/-0.01) for {'max_depth': 20, 'n_estimators': 50}
# 0.548 (+/-0.01) for {'max_depth': 20, 'n_estimators': 100}
# 0.544 (+/-0.056) for {'max_depth': None, 'n_estimators': 5}
# 0.564 (+/-0.028) for {'max_depth': None, 'n_estimators': 50}
# 0.57 (+/-0.015) for {'max_depth': None, 'n_estimators': 100}

# %%
rf3 = RandomForestClassifier(n_estimators=50,max_depth=None)
rf3.fit(tweet_tfidf_train,train['sentiment'])
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
y_pred = rf3.predict(tweet_tfidf_eval)
accuracy = round(metrics.accuracy_score(eval['sentiment'],y_pred), 3)
precision = round(metrics.precision_score(eval['sentiment'],y_pred,average="weighted"), 3)
recall = round(metrics.recall_score(eval['sentiment'],y_pred,average="weighted"), 3)
rf_f1_score = round(metrics.f1_score(eval['sentiment'], y_pred, average="weighted"), 3)
print('MAX DEPTH: {} / # OF EST: {} -- A: {} / P: {} / R: {}'.format(rf3.max_depth,
                                                                         rf3.n_estimators,
                                                                         accuracy,
                                                                         precision,
                                                                         recall))
# Out:
# MAX DEPTH: None / # OF EST: 50 -- A: 0.555 / P: 0.586 / R: 0.555

# %%
print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1_score: ", rf_f1_score)
# Out:
# Accuracy:  0.555
# Precision:  0.586
# Recall:  0.555
# F1_score:  0.51

# %%
print(rf_f1_score)
# Out:
# 0.51

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(rf3, tweet_tfidf_eval, eval['sentiment']) 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
plot_confusion_matrix(rf3, tweet_tfidf_eval, eval['sentiment'],normalize="true") 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
