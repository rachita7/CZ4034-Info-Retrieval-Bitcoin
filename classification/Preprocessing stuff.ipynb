# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/CZ4034IR/Classification/inference/hand-labelled-new/test_data_inference.csv')

# %%
df
# Out:
#       Unnamed: 0                                  processed_content  \
# 0              4  all you need to do be keep buy utc and eth and...
# 1              5  buy bitcoin on the bitstamp exchange this type...
# 2             12  a quick update on the recent performance of po...
# 3             19           utc bounce at 60300 rocket rocket rocket
# 4             21  sound like a good recipe to me smiling_face hu...
# ...          ...                                                ...
# 1144        7684  i do not know how you define hurt bitcoin but ...
# 1145        7695  i think everything be good for bitcoin go to b...
# 1146        7746  the chart look so shift that i be almost convi...
# 1147        7749  the market be bleed take a mutombo level rejec...
# 1148        7750  the 4 tokens be atlas polis tl and il all of w...
#
#       sentiment         username  \
# 0             1      Shamrock680
# 1             0         BskdTina
# 2             1         PigsterC
# 3             1  Stockwa60818438
# 4             1       CEOSCRYPTO
# ...         ...              ...
# 1144         -1             lopp
# 1145         -1             lopp
# 1146         -1      scottmelker
# 1147         -1      scottmelker
# 1148         -1      scottmelker
#
#                                                 content  \
# 0     @robertakanda @RobertOstler All you need to do...
# 1     Buying Bitcoins on the Bitstamp exchange. This...
# 2     A quick update on the recent performance of Pi...
# 3                               BTC bounce at 60300 🚀🚀🚀
# 4     Sounds like a good #CryptoEqualsOptions recipe...
# ...                                                 ...
# 1144  @NeerajKA @gladstein @bitcoin_hermit @coryklip...
# 1145  @gladstein @udiWertheimer i thought everything...
# 1146  The #Bitcoin chart looks so shitty that I'm al...
# 1147  The market is bleeding, #Bitcoin took a Mutomb...
# 1148  The 4 tokens are $ATLAS $POLIS $TLM and $ILV, ...
#
#                            date      country  replyCount  retweetCount  \
# 0     2021-12-27 23:52:56+00:00    Argentina           0             0
# 1     2021-12-27 22:30:40+00:00    Argentina           0             0
# 2     2021-12-26 22:28:22+00:00    Argentina           0             1
# 3     2021-10-29 07:23:35+00:00  Switzerland           0             0
# 4     2021-12-26 20:05:07+00:00    Argentina           0             0
# ...                         ...          ...         ...           ...
# 1144  2021-12-07 22:48:43+00:00          NaN           1             2
# 1145  2021-11-22 21:03:35+00:00          NaN           4             1
# 1146  2021-12-14 17:54:39+00:00          NaN         295           153
# 1147  2021-12-10 15:03:25+00:00          NaN          24             6
# 1148  2021-12-09 22:22:28+00:00          NaN          50            38
#
#       likeCount                                                url  \
# 0             0  https://twitter.com/Shamrock680/status/1475615...
# 1             3  https://twitter.com/BskdTina/status/1475595009...
# 2             1  https://twitter.com/PigsterC/status/1475232043...
# 3             0  https://twitter.com/Stockwa60818438/status/145...
# 4             1  https://twitter.com/CEOSCRYPTO/status/14751959...
# ...         ...                                                ...
# 1144         12  https://twitter.com/lopp/status/14683517954456...
# 1145         59  https://twitter.com/lopp/status/14628895224427...
# 1146       3444  https://twitter.com/scottmelker/status/1470814...
# 1147        109  https://twitter.com/scottmelker/status/1469321...
# 1148        212  https://twitter.com/scottmelker/status/1469069...
#
#       textblob_class  vader_class  inference
# 0                  0            0        1.0
# 1                  1            1        0.0
# 2                  1            1        1.0
# 3                  0            0        1.0
# 4                  1            1        1.0
# ...              ...          ...        ...
# 1144               1           -1       -1.0
# 1145               1            1        1.0
# 1146               0            1        1.0
# 1147               1           -1        1.0
# 1148               1           -1        0.0
#
# [1149 rows x 14 columns]

# %%
df[df.TextBlob_Analysis==df.sentiment] and not(df['sentiment'].isnull())]
# Out:
#   File "<ipython-input-4-6998842513c2>", line 1
#     df[df.TextBlob_Analysis==df.sentiment] and not(df['sentiment'].isnull())]
#                                                                             ^
# SyntaxError: invalid syntax

# %%
df.iloc[0]['content']

# %%
df['content']

# %%
# !pip install emot --upgrade
# Out:
# Collecting emot
#   Downloading emot-3.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 16 kB/s
# Installing collected packages: emot
# Successfully installed emot-3.1

# %%
from emot.emo_unicode import UNICODE_EMOJI,EMOTICONS_EMO

# %%
from emot.emo_unicode import UNICODE_EMOJI,EMOTICONS_EMO
# Converting emojis to words
def convert_emojis(text):
    for emot in UNICODE_EMOJI:
        text = text.replace(emot, "_".join(UNICODE_EMOJI[emot].replace(",","").replace(":","").split()))
        return text
# Converting emoticons to words    
def convert_emoticons(text):
    for emot in EMOTICONS_EMO:
        text = re.sub(u'\('+emot+'\)', "_".join(EMOTICONS_EMO[emot].replace(",","").split()), text)
        return text

# %%
#for now replaced emojis and emoticons instead of removing them
def remove_emoticons(text):
    emoticon_pattern = re.compile(u'(' + u'|'.join(k for k in EMOTICONS) + u')')
    return emoticon_pattern.sub(r'', text)

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 5.1 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=eb9aa577d0d1f6146170765e42fee5f4d6ecdd9fb844c1307f83c4954e4aa604
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-1.7.0

# %%
import emoji

# %%
def load_dict_smileys():
    
    return {
        ":‑)":"smiley",
        ":-]":"smiley",
        ":-3":"smiley",
        ":->":"smiley",
        "8-)":"smiley",
        ":-}":"smiley",
        ":)":"smiley",
        ":]":"smiley",
        ":3":"smiley",
        ":>":"smiley",
        "8)":"smiley",
        ":}":"smiley",
        ":o)":"smiley",
        ":c)":"smiley",
        ":^)":"smiley",
        "=]":"smiley",
        "=)":"smiley",
        ":-))":"smiley",
        ":‑D":"smiley",
        "8‑D":"smiley",
        "x‑D":"smiley",
        "X‑D":"smiley",
        ":D":"smiley",
        "8D":"smiley",
        "xD":"smiley",
        "XD":"smiley",
        ":‑(":"sad",
        ":‑c":"sad",
        ":‑<":"sad",
        ":‑[":"sad",
        ":(":"sad",
        ":c":"sad",
        ":<":"sad",
        ":[":"sad",
        ":-||":"sad",
        ">:[":"sad",
        ":{":"sad",
        ":@":"sad",
        ">:(":"sad",
        ":'‑(":"sad",
        ":'(":"sad",
        ":‑P":"playful",
        "X‑P":"playful",
        "x‑p":"playful",
        ":‑p":"playful",
        ":‑Þ":"playful",
        ":‑þ":"playful",
        ":‑b":"playful",
        ":P":"playful",
        "XP":"playful",
        "xp":"playful",
        ":p":"playful",
        ":Þ":"playful",
        ":þ":"playful",
        ":b":"playful",
        "<3":"love"
        }

# %%
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 5.3 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.4

# %%
import unidecode
def accented_characters_removal(text):
    # this is a docstring
    """
    The function will remove accented characters from the 
    text contained within the Dataset.
       
    arguments:
        input_text: "text" of type "String". 
                    
    return:
        value: "text" with removed accented characters.
        
    Example:
    Input : Málaga, àéêöhello
    Output : Malaga, aeeohello    
        
    """
    # Remove accented characters from text using unidecode.
    # Unidecode() - It takes unicode data & tries to represent it to ASCII characters. 
    text = unidecode.unidecode(text)
    return text

# %%
# !pip install autocorrect
# Out:
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      |████████████████████████████████| 622 kB 5.3 MB/s
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622382 sha256=feff5d94ead6ca6b551a7b1ce2438d21c8a7354141f8ec436b7b66fb2d70f41d
#   Stored in directory: /root/.cache/pip/wheels/54/d4/37/8244101ad50b0f7d9bffd93ce58ed7991ee1753b290923934b
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1

# %%
from nltk.tokenize import word_tokenize 
from nltk.stem import WordNetLemmatizer 
from autocorrect import Speller

# %%
# The code for spelling corrections
def spelling_correction(text):
    ''' 
    This function will correct spellings.
    
    arguments:
         input_text: "text" of type "String".
         
    return:
        value: Text after corrected spellings.
        
    Example: 
    Input : This is Oberois from Dlhi who came heree to studdy.
    Output : This is Oberoi from Delhi who came here to study.
      
    
    '''
    # Check for spellings in English language
    spell = Speller(lang='en')
    Corrected_text = spell(text)
    return Corrected_text

# %%
def clean_ascii(text):
        # function to remove non-ASCII chars from data
        return ''.join(i for i in text if ord(i) < 128)

# %%
import re
# function to remove numbers
def remove_numbers(text):
    # define the pattern to keep
    pattern = r'[^a-zA-z.,!?/:;\"\'\s]' 
    return re.sub(pattern, '', text)

# %%
# !!pip install contractions
# Out:
# ['Collecting contractions',
#  '  Downloading contractions-0.1.68-py2.py3-none-any.whl (8.1 kB)',
#  'Collecting textsearch>=0.0.21',
#  '  Downloading textsearch-0.0.21-py2.py3-none-any.whl (7.5 kB)',
#  'Collecting anyascii',
#  '  Downloading anyascii-0.3.0-py3-none-any.whl (284 kB)',
#  '\x1b[?25l',
#  '\x1b[K     |█▏                              | 10 kB 17.5 MB/s eta 0:00:01',
#  '\x1b[K     |██▎                             | 20 kB 21.0 MB/s eta 0:00:01',
#  '\x1b[K     |███▌                            | 30 kB 14.6 MB/s eta 0:00:01',
#  '\x1b[K     |████▋                           | 40 kB 4.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████▊                          | 51 kB 4.8 MB/s eta 0:00:01',
#  '\x1b[K     |███████                         | 61 kB 5.6 MB/s eta 0:00:01',
#  '\x1b[K     |████████                        | 71 kB 5.4 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▏                      | 81 kB 5.3 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▍                     | 92 kB 5.9 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▌                    | 102 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▊                   | 112 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▉                  | 122 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████                 | 133 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▏               | 143 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▎              | 153 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▍             | 163 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▋            | 174 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▊           | 184 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████          | 194 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████         | 204 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▏       | 215 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▍      | 225 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▌     | 235 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▋    | 245 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▉   | 256 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████  | 266 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▏| 276 kB 5.0 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 284 kB 5.0 MB/s ',
#  '\x1b[?25hCollecting pyahocorasick',
#  '  Downloading pyahocorasick-1.4.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)',
#  '\x1b[?25l',
#  '\x1b[K     |███                             | 10 kB 22.6 MB/s eta 0:00:01',
#  '\x1b[K     |██████▏                         | 20 kB 28.3 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▎                      | 30 kB 35.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▎                   | 40 kB 40.2 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▍                | 51 kB 43.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▌             | 61 kB 46.6 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▌          | 71 kB 48.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▋       | 81 kB 49.9 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▊    | 92 kB 52.4 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▊ | 102 kB 54.4 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 106 kB 54.4 MB/s ',
#  '\x1b[?25hInstalling collected packages: pyahocorasick, anyascii, textsearch, contractions',
#  'Successfully installed anyascii-0.3.0 contractions-0.1.68 pyahocorasick-1.4.4 textsearch-0.0.21']

# %%
import contractions
def expand_contractions(text):
  return contractions.fix(text)

# %%
import nltk
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()
def lemmatization(text):
    """This function converts word to their root words 
       without explicitely cut down as done in stemming.
    
    arguments:
         input_text: "text" of type "String".
         
    return:
        value: Text having root words only, no tense form, no plural forms
        
    Example: 
    Input : text reduced 
    Output :  text reduce
    
   """
    # Converting words to their root forms
    
    lemma = [lemmatizer.lemmatize(w,'v') for w in w_tokenizer.tokenize(text)]
    return lemma

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from nltk.corpus import stopwords
# Out:
# <style>table.dataframe td{white-space: nowrap;}</style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# <style>table.dataframe td{white-space: nowrap;}</style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def tweet_to_words(tweet):
    text = tweet.lower()
   
    # Code to remove the Hashtags from the text
    text=re.sub(r'\B#\S+','',text)

    # print(text)
    # Code to remove the links from the text
    text=re.sub(r"http\S+", "",text)
    text=re.sub(r"\ [A-Za-z]*\.com", " ",text)
    # Code to substitute the multiple spaces with single spaces
    text=re.sub(r'\s+', ' ', text, flags=re.I)
    # Remove the twitter handlers
    text=re.sub('@[^\s]+','',text)
    # print(text)

    # text=convert_emoticons(text)
    SMILEY = load_dict_smileys()  
    words = text.split()
    reformed = [SMILEY[word] if word in SMILEY else word for word in words]
    text = " ".join(reformed)

    # text=convert_emojis(text)
    #can check which version is better
    text = emoji.demojize(text)
    # print(text)
    text=accented_characters_removal(text)
    text=expand_contractions(text)

    # Code to remove the Special characters from the text 
    text=' '.join(re.findall(r'\w+', text))
    # text=remove_numbers(text)

    # print(text)
    text=spelling_correction(text)
    text=lemmatization(text)
    # text=clean_ascii(text)


    return text


    

    # tokenize
    # words = text.split()

# %%
def tweet_to_words(tweet):
    text = tweet.lower()
   
    # Code to remove the Hashtags from the text
    text=re.sub(r'\B#\S+','',text)

    # print(text)
    # Code to remove the links from the text
    text=re.sub(r"http\S+", "",text)
    text=re.sub(r"\ [A-Za-z]*\.com", " ",text)
    # Code to substitute the multiple spaces with single spaces
    text=re.sub(r'\s+', ' ', text, flags=re.I)
    # Remove the twitter handlers
    text=re.sub('@[^\s]+','',text)
  

  
    SMILEY = load_dict_smileys()  
    words = text.split()
    reformed = [SMILEY[word] if word in SMILEY else word for word in words]
    text = " ".join(reformed)

 
    text = emoji.demojize(text)
    text=accented_characters_removal(text)
    text=expand_contractions(text)

    # Code to remove the Special characters from the text 
    text=' '.join(re.findall(r'\w+', text))
  

   
    text=spelling_correction(text)
    text=lemmatization(text)
    

    return text


    

    # tokenize
    # words = text.split()

# %%
print(tweet_to_words("Not shorting but waiting for a little of consolidation and down swings because is New Moon and new moons are always bearish #bitcoin"))
# Out:
# ['not', 'sort', 'but', 'wait', 'for', 'a', 'little', 'of', 'consolidation', 'and', 'down', 'swing', 'because', 'be', 'new', 'moon', 'and', 'new', 'moon', 'be', 'always', 'parish']

# %%
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)
# Out:
# <style>table.dataframe td{white-space: nowrap;}</style>

# %%
df.iloc[1]['content']
# Out:
# 'Buying Bitcoins on the Bitstamp exchange. This type of trading is a long-term investment by holding bitcoin assets and selling them for a profit when the price rises significantly.\n\nhttps://t.co/iChdbpVsdH'

# %%
print(tweet_to_words(df.iloc[1]['content']))
# Out:
# <style>table.dataframe td{white-space: nowrap;}</style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ['buy', 'bitcoin', 'on', 'the', 'bitstamp', 'exchange', 'this', 'type', 'of', 'trade', 'be', 'a', 'long', 'term', 'investment', 'by', 'hold', 'bitcoin', 'assets', 'and', 'sell', 'them', 'for', 'a', 'profit', 'when', 'the', 'price', 'rise', 'significantly']

# %%
print(tweet_to_words("Not shorting but waiting for a little of consolidation and down swings because is New Moon and new moons are always bearish #bitcoin"))
# Out:
# ['not', 'short', 'but', 'wait', 'for', 'a', 'little', 'of', 'consolidation', 'and', 'down', 'swing', 'because', 'be', 'new', 'moon', 'and', 'new', 'moon', 'be', 'always', 'bearish']

# %%
df.head()
# Out:
#    Unnamed: 0                   id                       date  \
# 0           0  1475536058389512203  2021-12-27 18:36:25+00:00
# 1           1  1475454075881799685  2021-12-27 13:10:38+00:00
# 2           2  1475143978655924228  2021-12-26 16:38:26+00:00
# 3           3  1475101412690436096  2021-12-26 13:49:17+00:00
# 4           4  1474736943221153797  2021-12-25 13:41:01+00:00
#
#                                                  url  \
# 0  https://twitter.com/saylor/status/147553605838...
# 1  https://twitter.com/saylor/status/147545407588...
# 2  https://twitter.com/saylor/status/147514397865...
# 3  https://twitter.com/saylor/status/147510141269...
# 4  https://twitter.com/saylor/status/147473694322...
#
#                                              content username  replyCount  \
# 0  #Bitcoin is digital property at low frequency,...   saylor         720
# 1                          #Bitcoin appreciates you.   saylor        1205
# 2  A review of #Bitcoin &amp; #Crypto regulation ...   saylor         809
# 3  If you want to fix the thing, put some #bitcoi...   saylor        1207
# 4  "I don't want a lot for Christmas. There is ju...   saylor        1000
#
#    retweetCount  likeCount  quoteCount                            hashtags  \
# 0           646       4077          51            ['Bitcoin', 'Lightning']
# 1          1307      14183          91                         ['Bitcoin']
# 2           553       3533          30  ['Bitcoin', 'Crypto', 'Lightning']
# 3          1144      11748          94                         ['bitcoin']
# 4          1167      11748          56                         ['Bitcoin']
#
#    sentiment  Unnamed: 12
# 0        1.0          NaN
# 1        NaN          NaN
# 2        0.0          NaN
# 3        1.0          NaN
# 4        1.0          NaN

# %%
testing=df.iloc[0]['content']

# %%
testing
# Out:
# '@chitaglorya__ @BTC_NFT @CryptoZillaVC @Block_Flash @BitcoinQueen96 @rhenz_625 @ErenSollar @alexcopilla thank you for this huge opportunity  to win🙏🙏🍀 https://t.co/uRq6k4qV7Q'

# %%
testing_output=tweet_to_words(testing)

# %%
testing1=' y\'all @chitaglorya__ @BTC_NFT @CryptoZillaVC @Block_Flash @BitcoinQueen96 @rhenz_625 @ErenSollar @alexcopilla thank you for this huge opportunity  to win🙏🙏🍀 https://t.co/uRq6k4qV7Q'

# %%
testing_output=tweet_to_words(testing1)

# %%
testing2='He is 😭'
print(emoji.demojize(testing2))
# Out:
# He is :loudly_crying_face:

# %%
testing_output=tweet_to_words(testing2)

# %%
df['processed']=df['content']

# %%
import tqdm

# %%
cleantext=[]
i=0
for item in df['content']:
    if type(item)==float:
      item = str(item)
    words=tweet_to_words(item)
    cleantext+=[words]
    i+=1
    if i%500==0:
      print(i)
df['cleantext_no_spell']=cleantext
df
# Out:
# 500
# 1000
#       Unnamed: 0                                  processed_content  \
# 0              4  all you need to do be keep buy utc and eth and...
# 1              5  buy bitcoin on the bitstamp exchange this type...
# 2             12  a quick update on the recent performance of po...
# 3             19           utc bounce at 60300 rocket rocket rocket
# 4             21  sound like a good recipe to me smiling_face hu...
# ...          ...                                                ...
# 1144        7684  i do not know how you define hurt bitcoin but ...
# 1145        7695  i think everything be good for bitcoin go to b...
# 1146        7746  the chart look so shift that i be almost convi...
# 1147        7749  the market be bleed take a mutombo level rejec...
# 1148        7750  the 4 tokens be atlas polis tl and il all of w...
#
#       sentiment         username  \
# 0             1      Shamrock680
# 1             0         BskdTina
# 2             1         PigsterC
# 3             1  Stockwa60818438
# 4             1       CEOSCRYPTO
# ...         ...              ...
# 1144         -1             lopp
# 1145         -1             lopp
# 1146         -1      scottmelker
# 1147         -1      scottmelker
# 1148         -1      scottmelker
#
#                                                 content  \
# 0     @robertakanda @RobertOstler All you need to do...
# 1     Buying Bitcoins on the Bitstamp exchange. This...
# 2     A quick update on the recent performance of Pi...
# 3                               BTC bounce at 60300 🚀🚀🚀
# 4     Sounds like a good #CryptoEqualsOptions recipe...
# ...                                                 ...
# 1144  @NeerajKA @gladstein @bitcoin_hermit @coryklip...
# 1145  @gladstein @udiWertheimer i thought everything...
# 1146  The #Bitcoin chart looks so shitty that I'm al...
# 1147  The market is bleeding, #Bitcoin took a Mutomb...
# 1148  The 4 tokens are $ATLAS $POLIS $TLM and $ILV, ...
#
#                            date      country  replyCount  retweetCount  \
# 0     2021-12-27 23:52:56+00:00    Argentina           0             0
# 1     2021-12-27 22:30:40+00:00    Argentina           0             0
# 2     2021-12-26 22:28:22+00:00    Argentina           0             1
# 3     2021-10-29 07:23:35+00:00  Switzerland           0             0
# 4     2021-12-26 20:05:07+00:00    Argentina           0             0
# ...                         ...          ...         ...           ...
# 1144  2021-12-07 22:48:43+00:00          NaN           1             2
# 1145  2021-11-22 21:03:35+00:00          NaN           4             1
# 1146  2021-12-14 17:54:39+00:00          NaN         295           153
# 1147  2021-12-10 15:03:25+00:00          NaN          24             6
# 1148  2021-12-09 22:22:28+00:00          NaN          50            38
#
#       likeCount                                                url  \
# 0             0  https://twitter.com/Shamrock680/status/1475615...
# 1             3  https://twitter.com/BskdTina/status/1475595009...
# 2             1  https://twitter.com/PigsterC/status/1475232043...
# 3             0  https://twitter.com/Stockwa60818438/status/145...
# 4             1  https://twitter.com/CEOSCRYPTO/status/14751959...
# ...         ...                                                ...
# 1144         12  https://twitter.com/lopp/status/14683517954456...
# 1145         59  https://twitter.com/lopp/status/14628895224427...
# 1146       3444  https://twitter.com/scottmelker/status/1470814...
# 1147        109  https://twitter.com/scottmelker/status/1469321...
# 1148        212  https://twitter.com/scottmelker/status/1469069...
#
#       textblob_class  vader_class  inference  \
# 0                  0            0        1.0
# 1                  1            1        0.0
# 2                  1            1        1.0
# 3                  0            0        1.0
# 4                  1            1        1.0
# ...              ...          ...        ...
# 1144               1           -1       -1.0
# 1145               1            1        1.0
# 1146               0            1        1.0
# 1147               1           -1        1.0
# 1148               1           -1        0.0
#
#                                      cleantext_no_spell
# 0     all you need to do be keep buy btc and eth and...
# 1     buy bitcoins on the bitstamp exchange this typ...
# 2     a quick update on the recent performance of pi...
# 3              btc bounce at 60300 rocket rocket rocket
# 4     sound like a good recipe to me smiling_face hu...
# ...                                                 ...
# 1144  i do not know how you define hurt bitcoin but ...
# 1145  i think everything be good for bitcoin go to b...
# 1146  the chart look so shitty that i be almost conv...
# 1147  the market be bleed take a mutombo level rejec...
# 1148  the 4 tokens be atlas polis tlm and ilv all of...
#
# [1149 rows x 15 columns]

# %%
cleantext=[]
i=0
for item in df['content']:
    if type(item)==float:
      item = str(item)
    words=tweet_to_words(item)
    cleantext+=[words]
    i+=1
    if i%500==0:
      print(i)
df['cleantext_no_spell_no_lemma']=cleantext
df
# Out:
# 500
# 1000
#       Unnamed: 0                                  processed_content  \
# 0              4  all you need to do be keep buy utc and eth and...
# 1              5  buy bitcoin on the bitstamp exchange this type...
# 2             12  a quick update on the recent performance of po...
# 3             19           utc bounce at 60300 rocket rocket rocket
# 4             21  sound like a good recipe to me smiling_face hu...
# ...          ...                                                ...
# 1144        7684  i do not know how you define hurt bitcoin but ...
# 1145        7695  i think everything be good for bitcoin go to b...
# 1146        7746  the chart look so shift that i be almost convi...
# 1147        7749  the market be bleed take a mutombo level rejec...
# 1148        7750  the 4 tokens be atlas polis tl and il all of w...
#
#       sentiment         username  \
# 0             1      Shamrock680
# 1             0         BskdTina
# 2             1         PigsterC
# 3             1  Stockwa60818438
# 4             1       CEOSCRYPTO
# ...         ...              ...
# 1144         -1             lopp
# 1145         -1             lopp
# 1146         -1      scottmelker
# 1147         -1      scottmelker
# 1148         -1      scottmelker
#
#                                                 content  \
# 0     @robertakanda @RobertOstler All you need to do...
# 1     Buying Bitcoins on the Bitstamp exchange. This...
# 2     A quick update on the recent performance of Pi...
# 3                               BTC bounce at 60300 🚀🚀🚀
# 4     Sounds like a good #CryptoEqualsOptions recipe...
# ...                                                 ...
# 1144  @NeerajKA @gladstein @bitcoin_hermit @coryklip...
# 1145  @gladstein @udiWertheimer i thought everything...
# 1146  The #Bitcoin chart looks so shitty that I'm al...
# 1147  The market is bleeding, #Bitcoin took a Mutomb...
# 1148  The 4 tokens are $ATLAS $POLIS $TLM and $ILV, ...
#
#                            date      country  replyCount  retweetCount  \
# 0     2021-12-27 23:52:56+00:00    Argentina           0             0
# 1     2021-12-27 22:30:40+00:00    Argentina           0             0
# 2     2021-12-26 22:28:22+00:00    Argentina           0             1
# 3     2021-10-29 07:23:35+00:00  Switzerland           0             0
# 4     2021-12-26 20:05:07+00:00    Argentina           0             0
# ...                         ...          ...         ...           ...
# 1144  2021-12-07 22:48:43+00:00          NaN           1             2
# 1145  2021-11-22 21:03:35+00:00          NaN           4             1
# 1146  2021-12-14 17:54:39+00:00          NaN         295           153
# 1147  2021-12-10 15:03:25+00:00          NaN          24             6
# 1148  2021-12-09 22:22:28+00:00          NaN          50            38
#
#       likeCount                                                url  \
# 0             0  https://twitter.com/Shamrock680/status/1475615...
# 1             3  https://twitter.com/BskdTina/status/1475595009...
# 2             1  https://twitter.com/PigsterC/status/1475232043...
# 3             0  https://twitter.com/Stockwa60818438/status/145...
# 4             1  https://twitter.com/CEOSCRYPTO/status/14751959...
# ...         ...                                                ...
# 1144         12  https://twitter.com/lopp/status/14683517954456...
# 1145         59  https://twitter.com/lopp/status/14628895224427...
# 1146       3444  https://twitter.com/scottmelker/status/1470814...
# 1147        109  https://twitter.com/scottmelker/status/1469321...
# 1148        212  https://twitter.com/scottmelker/status/1469069...
#
#       textblob_class  vader_class  inference  \
# 0                  0            0        1.0
# 1                  1            1        0.0
# 2                  1            1        1.0
# 3                  0            0        1.0
# 4                  1            1        1.0
# ...              ...          ...        ...
# 1144               1           -1       -1.0
# 1145               1            1        1.0
# 1146               0            1        1.0
# 1147               1           -1        1.0
# 1148               1           -1        0.0
#
#                                      cleantext_no_spell  \
# 0     all you need to do be keep buy btc and eth and...
# 1     buy bitcoins on the bitstamp exchange this typ...
# 2     a quick update on the recent performance of pi...
# 3              btc bounce at 60300 rocket rocket rocket
# 4     sound like a good recipe to me smiling_face hu...
# ...                                                 ...
# 1144  i do not know how you define hurt bitcoin but ...
# 1145  i think everything be good for bitcoin go to b...
# 1146  the chart look so shitty that i be almost conv...
# 1147  the market be bleed take a mutombo level rejec...
# 1148  the 4 tokens be atlas polis tlm and ilv all of...
#
#                             cleantext_no_spell_no_lemma
# 0     all you need to do is keep buying btc and eth ...
# 1     buying bitcoins on the bitstamp exchange this ...
# 2     a quick update on the recent performance of pi...
# 3              btc bounce at 60300 rocket rocket rocket
# 4     sounds like a good recipe to me smiling_face h...
# ...                                                 ...
# 1144  i do not know how you define hurting bitcoin b...
# 1145  i thought everything was good for bitcoin goin...
# 1146  the chart looks so shitty that i am almost con...
# 1147  the market is bleeding took a mutombo level re...
# 1148  the 4 tokens are atlas polis tlm and ilv all o...
#
# [1149 rows x 16 columns]
